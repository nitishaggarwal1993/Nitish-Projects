# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import cv2
import matplotlib.pyplot as plt

# %%
import cv2 , glob , numpy
def scaleRadius(img,scale):
    x = img[img.shape[0]//2,:,:].sum(1)
    r = (x>x.mean()/10).sum()/2
    s = scale*1.0/r
    return cv2.resize(img,(0,0), fx=s, fy=s)

scale = 300
# for f in glob.glob("train/*.jpeg") + glob.glob("test/*.jpeg"):
#     try:
#         a = cv2.imread(f)
#         #scale image to a given radius
#         a = scaleRadius(a,scale)
#         #subtract local mean colour
#         a = cv2.addWeighted(a, 4, cv2.GaussianBlur(a,(0,0),scale/30, -4, 128)
#         #remove outer 10%
#         b = numpy.zeros(a.shape)
#         cv2.circle (b, (a.shape[1]/2, a.shape[0]/2), int(scale*0.9), (1,1,1), -1, 8, 0)
#         a = a*b + 128*(1-b)
#         cv2.imwrite(str(scale) + "_" + f,a)
#     expect:
#         print(f)

# %%
a = cv2.imread('10_left.jpeg',-1)
a = cv2.cvtColor(a, cv2.COLOR_BGR2RGB)

# %%
_ = plt.hist(a[a.shape[0]//2,:,:].sum(1),bins=100)

# %%
a[a.shape[0]//2,:,:].sum(1).mean()/10
# Out:
# 24.190046296296295

# %%
a[a.shape[0]/2,:,:].shape
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 a[a.shape[0]/2,:,:].shape
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
plt.imshow(a)

# %%
a_scaled = scaleRadius(a,scale)
# plt.imshow(a_scaled)
a.shape
# Out:
# (3168, 4752, 3)

# %%
middle_row_index = a.shape[0]//2
middle_row = a[middle_row_index,:,:]
middle_row.shape
x = middle_row.sum(axis=1)
x.shape
black_pixel_threshold = x.mean() / 10
black_pixel_threshold
# plt.plot(x)
# plt.imshow(middle_row)
# Out:
# 24.190046296296295

# %%
middle_row.max()
# Out:
# 0

# %%
# sum across channels at middle row
x = a[a.shape[0]//2,:,:].sum(axis=1)
a[a.shape[0]//2,:,:].shape, x.shape
# Out:
# ((4752, 3), (4752,))

# %%
# find count of pixels in middle row where we have value more than 0.1 times mean, a proxy for how big image radius is.
(x>x.mean()/10).sum()/2
# Out:
# 1504.5

# %%
# scale image in a way that radius becomes 300. To bring unofrmity in size of images. i.e if r=600, scale image to 1/2 of it's size etc.
s = scale*1.0/r
a_scaled = cv2.resize(img,(0,0), fx=s, fy=s)

# %%
# Out:
# (4752, 3)
